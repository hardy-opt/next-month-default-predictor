# %%
import joblib
import pandas as pd
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay

# Load test data
X_test = joblib.load('../data/processed/X_test.pkl')
y_test = joblib.load('../data/processed/y_test.pkl')

# Load trained models
logit_model = joblib.load('../models/logistic_regression.joblib')
rf_model = joblib.load('../models/random_forest.joblib')
xgb_model = joblib.load('../models/xgboost.joblib')

# %%
models = {
    "Logistic Regression": logit_model,
    "Random Forest": rf_model,
    "XGBoost": xgb_model
}

for name, model in models.items():
    print(f"### {name} ###")
    y_pred = model.predict(X_test)
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    ConfusionMatrixDisplay.from_estimator(model, X_test, y_test).plot()
# Out:
# ### Logistic Regression ###
# Accuracy: 0.6898333333333333
#               precision    recall  f1-score   support
#
#            0       0.88      0.70      0.78      4687
#            1       0.38      0.66      0.48      1313
#
#     accuracy                           0.69      6000
#    macro avg       0.63      0.68      0.63      6000
# weighted avg       0.77      0.69      0.71      6000
#
# ### Random Forest ###
# Accuracy: 0.7921666666666667
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.87      4687
#            1       0.53      0.46      0.49      1313
#
#     accuracy                           0.79      6000
#    macro avg       0.69      0.67      0.68      6000
# weighted avg       0.78      0.79      0.79      6000
#
# ### XGBoost ###
# Accuracy: 0.8021666666666667
#               precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88      4687
#            1       0.57      0.41      0.48      1313
#
#     accuracy                           0.80      6000
#    macro avg       0.71      0.66      0.68      6000
# weighted avg       0.79      0.80      0.79      6000

# %%
# If one wants to add ROC curves or feature importances for RF/XGBoost
import matplotlib.pyplot as plt

xgb_model.feature_importances_
rf_model.feature_importances_
# Out:
# array([0.08012341, 0.01151473, 0.02572315, 0.01258777, 0.06295607,
#        0.11052706, 0.0421775 , 0.03232337, 0.02990236, 0.02244464,
#        0.02542031, 0.05212567, 0.04603407, 0.04244888, 0.04184176,
#        0.0427421 , 0.04296421, 0.04827285, 0.04834947, 0.0446479 ,
#        0.0447118 , 0.04276112, 0.04739981])
