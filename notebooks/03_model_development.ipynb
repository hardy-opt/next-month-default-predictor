# %%
import joblib
import pandas as pd
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay

# Load test data
X_test = joblib.load('../data/processed/X_test.pkl')
y_test = joblib.load('../data/processed/y_test.pkl')

# Load trained models
logit_model = joblib.load('../models/logistic_regression.joblib')
rf_model = joblib.load('../models/random_forest.joblib')
xgb_model = joblib.load('../models/xgboost.joblib')

# %%
models = {
    "Logistic Regression": logit_model,
    "Random Forest": rf_model,
    "XGBoost": xgb_model
}

for name, model in models.items():
    print(f"### {name} ###")
    y_pred = model.predict(X_test)
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    ConfusionMatrixDisplay.from_estimator(model, X_test, y_test).plot()
# Out:
# ### Logistic Regression ###
# Accuracy: 0.683
#               precision    recall  f1-score   support
#
#            0       0.88      0.69      0.77      4687
#            1       0.37      0.66      0.48      1313
#
#     accuracy                           0.68      6000
#    macro avg       0.63      0.68      0.63      6000
# weighted avg       0.77      0.68      0.71      6000
#
# ### Random Forest ###
# Accuracy: 0.7921666666666667
#               precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87      4687
#            1       0.53      0.47      0.50      1313
#
#     accuracy                           0.79      6000
#    macro avg       0.69      0.68      0.68      6000
# weighted avg       0.78      0.79      0.79      6000
#
# ### XGBoost ###
# Accuracy: 0.7975
#               precision    recall  f1-score   support
#
#            0       0.86      0.89      0.87      4687
#            1       0.54      0.47      0.50      1313
#
# ...

# %%
# If one wants to add ROC curves or feature importances for RF/XGBoost
import matplotlib.pyplot as plt

xgb_model.feature_importances_
rf_model.feature_importances_
# Out:
# array([0.07687001, 0.0119004 , 0.02706031, 0.01277805, 0.06164191,
#        0.10391061, 0.04723184, 0.03561042, 0.02883291, 0.02054764,
#        0.02418145, 0.05189182, 0.04456748, 0.04331004, 0.04107822,
#        0.04227906, 0.04309222, 0.05151006, 0.04886511, 0.04567158,
#        0.04405553, 0.0443323 , 0.04878105])
